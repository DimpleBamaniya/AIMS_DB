-- %% [markdown]
-- # [AIMSV3]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [AIMSV3]    Script Date: 02-01-2025 11:41:38 ******/
CREATE DATABASE [AIMSV3]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'AIMSV3', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\AIMSV3.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'AIMSV3_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\AIMSV3_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [AIMSV3] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [AIMSV3].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [AIMSV3] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [AIMSV3] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [AIMSV3] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [AIMSV3] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [AIMSV3] SET ARITHABORT OFF 
GO
ALTER DATABASE [AIMSV3] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [AIMSV3] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [AIMSV3] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [AIMSV3] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [AIMSV3] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [AIMSV3] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [AIMSV3] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [AIMSV3] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [AIMSV3] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [AIMSV3] SET  ENABLE_BROKER 
GO
ALTER DATABASE [AIMSV3] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [AIMSV3] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [AIMSV3] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [AIMSV3] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [AIMSV3] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [AIMSV3] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [AIMSV3] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [AIMSV3] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [AIMSV3] SET  MULTI_USER 
GO
ALTER DATABASE [AIMSV3] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [AIMSV3] SET DB_CHAINING OFF 
GO
ALTER DATABASE [AIMSV3] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [AIMSV3] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [AIMSV3] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [AIMSV3] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [AIMSV3] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Brands]

-- %%
USE [AIMSV3]
GO

-- %%
/****** Object:  Table [dbo].[Brands]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Brands](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NULL,
	[Value] [int] NULL,
	[IsActive] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Categories]

-- %%
/****** Object:  Table [dbo].[Categories]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categories](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](150) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[Created] [date] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cities]

-- %%
/****** Object:  Table [dbo].[Cities]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cities](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
 CONSTRAINT [PK_Cities] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_Cities_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Departments]

-- %%
/****** Object:  Table [dbo].[Departments]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Departments](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[Created] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Models]

-- %%
/****** Object:  Table [dbo].[Models]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Models](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[name] [varchar](255) NULL,
	[Value] [int] NULL,
	[BrandID] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Products]

-- %%
/****** Object:  Table [dbo].[Products]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Products](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[CategoryID] [int] NULL,
	[BrandID] [int] NOT NULL,
	[Quantity] [int] NULL,
	[UseQuantity] [int] NULL,
	[AvailableQuantity] [int] NULL,
	[IsActive] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_Products_CategoryID_BrandID] UNIQUE NONCLUSTERED 
(
	[CategoryID] ASC,
	[BrandID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserProducts]

-- %%
/****** Object:  Table [dbo].[UserProducts]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserProducts](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[UserID] [int] NOT NULL,
	[ProductID] [int] NOT NULL,
	[AssignedDate] [date] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_UserProduct] UNIQUE NONCLUSTERED 
(
	[UserID] ASC,
	[ProductID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[FirstName] [varchar](100) NOT NULL,
	[LastName] [varchar](100) NOT NULL,
	[EmailID] [varchar](100) NOT NULL,
	[Password] [varchar](100) NOT NULL,
	[CityID] [int] NULL,
	[DepartmentID] [int] NULL,
	[Permissions] [bit] NULL,
	[Created] [date] NOT NULL,
	[CreatedBy] [int] NOT NULL,
	[Modified] [date] NULL,
	[ModifiedBy] [int] NULL,
	[IsDeleted] [bit] NOT NULL,
	[Deleted] [date] NULL,
	[DeletedBy] [int] NULL,
 CONSTRAINT [PK__Users__3214EC273AFCA909] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_Users_EmailID_Password] UNIQUE NONCLUSTERED 
(
	[EmailID] ASC,
	[Password] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_Users_FirstName_LastName] UNIQUE NONCLUSTERED 
(
	[FirstName] ASC,
	[LastName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_Users_IsActive]

-- %%
ALTER TABLE [dbo].[Brands] ADD  CONSTRAINT [DF_Users_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Categorie__IsAct__08B54D69]

-- %%
ALTER TABLE [dbo].[Categories] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Categorie__Creat__09A971A2]

-- %%
ALTER TABLE [dbo].[Categories] ADD  DEFAULT (getdate()) FOR [Created]
GO

-- %% [markdown]
-- # [DF__Cities__IsActive__634EBE90]

-- %%
ALTER TABLE [dbo].[Cities] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Departmen__IsAct__74AE54BC]

-- %%
ALTER TABLE [dbo].[Departments] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Departmen__Creat__75A278F5]

-- %%
ALTER TABLE [dbo].[Departments] ADD  DEFAULT (getdate()) FOR [Created]
GO

-- %% [markdown]
-- # [DF_Models_IsActive]

-- %%
ALTER TABLE [dbo].[Models] ADD  CONSTRAINT [DF_Models_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF_Products_UseQuantity]

-- %%
ALTER TABLE [dbo].[Products] ADD  CONSTRAINT [DF_Products_UseQuantity]  DEFAULT (NULL) FOR [UseQuantity]
GO

-- %% [markdown]
-- # [DF_Products_AvailableQuantity]

-- %%
ALTER TABLE [dbo].[Products] ADD  CONSTRAINT [DF_Products_AvailableQuantity]  DEFAULT (NULL) FOR [AvailableQuantity]
GO

-- %% [markdown]
-- # [DF_Products_IsActive]

-- %%
ALTER TABLE [dbo].[Products] ADD  CONSTRAINT [DF_Products_IsActive]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__UserProdu__Assig__40C49C62]

-- %%
ALTER TABLE [dbo].[UserProducts] ADD  DEFAULT (getdate()) FOR [AssignedDate]
GO

-- %% [markdown]
-- # [DF_Users_IsDeleted]

-- %%
ALTER TABLE [dbo].[Users] ADD  CONSTRAINT [DF_Users_IsDeleted]  DEFAULT ((0)) FOR [IsDeleted]
GO

-- %% [markdown]
-- # [FK_Models_BrandID]

-- %%
ALTER TABLE [dbo].[Models]  WITH CHECK ADD  CONSTRAINT [FK_Models_BrandID] FOREIGN KEY([BrandID])
REFERENCES [dbo].[Brands] ([ID])
GO
ALTER TABLE [dbo].[Models] CHECK CONSTRAINT [FK_Models_BrandID]
GO

-- %% [markdown]
-- # [FK_Products_BrandID]

-- %%
ALTER TABLE [dbo].[Products]  WITH CHECK ADD  CONSTRAINT [FK_Products_BrandID] FOREIGN KEY([BrandID])
REFERENCES [dbo].[Brands] ([ID])
GO
ALTER TABLE [dbo].[Products] CHECK CONSTRAINT [FK_Products_BrandID]
GO

-- %% [markdown]
-- # [FK_Products_CategoryID]

-- %%
ALTER TABLE [dbo].[Products]  WITH CHECK ADD  CONSTRAINT [FK_Products_CategoryID] FOREIGN KEY([CategoryID])
REFERENCES [dbo].[Categories] ([ID])
GO
ALTER TABLE [dbo].[Products] CHECK CONSTRAINT [FK_Products_CategoryID]
GO

-- %% [markdown]
-- # [FK__UserProdu__Produ__42ACE4D4]

-- %%
ALTER TABLE [dbo].[UserProducts]  WITH CHECK ADD FOREIGN KEY([ProductID])
REFERENCES [dbo].[Products] ([ID])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__UserProdu__UserI__41B8C09B]

-- %%
ALTER TABLE [dbo].[UserProducts]  WITH CHECK ADD  CONSTRAINT [FK__UserProdu__UserI__41B8C09B] FOREIGN KEY([UserID])
REFERENCES [dbo].[Users] ([ID])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[UserProducts] CHECK CONSTRAINT [FK__UserProdu__UserI__41B8C09B]
GO

-- %% [markdown]
-- # [FK_Users_CityID]

-- %%
ALTER TABLE [dbo].[Users]  WITH CHECK ADD  CONSTRAINT [FK_Users_CityID] FOREIGN KEY([CityID])
REFERENCES [dbo].[Cities] ([ID])
GO
ALTER TABLE [dbo].[Users] CHECK CONSTRAINT [FK_Users_CityID]
GO

-- %% [markdown]
-- # [FK_Users_DepartmentID]

-- %%
ALTER TABLE [dbo].[Users]  WITH CHECK ADD  CONSTRAINT [FK_Users_DepartmentID] FOREIGN KEY([DepartmentID])
REFERENCES [dbo].[Departments] ([ID])
GO
ALTER TABLE [dbo].[Users] CHECK CONSTRAINT [FK_Users_DepartmentID]
GO

-- %% [markdown]
-- # [dbo].[usp.UpdateAvailableQuantity]

-- %%
/****** Object:  StoredProcedure [dbo].[usp.UpdateAvailableQuantity]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE   PROCEDURE [dbo].[usp.UpdateAvailableQuantity]
AS
BEGIN
    -- Set NOCOUNT ON to avoid extra result sets
    SET NOCOUNT ON;

    -- Update AvailableQuantity in the Products table
    UPDATE p
    SET AvailableQuantity = p.Quantity - ISNULL(up.UseQuantity, 0)
    FROM [dbo].[Products] p
    LEFT JOIN (
        -- Calculate UseQuantity from UserProducts table
        SELECT 
            up.ProductID,
            COUNT(up.UserProductID) AS UseQuantity
        FROM [dbo].[UserProducts] up
        GROUP BY up.ProductID
    ) up ON p.ID = up.ProductID;

END
GO

-- %% [markdown]
-- # [dbo].[usp.UpdateAvailableQuantityAndUseQuantity]

-- %%
/****** Object:  StoredProcedure [dbo].[usp.UpdateAvailableQuantityAndUseQuantity]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
/* 
-- Execute the stored procedure
EXEC [dbo].[usp.UpdateAvailableQuantityAndUseQuantity];
*/


CREATE   PROCEDURE [dbo].[usp.UpdateAvailableQuantityAndUseQuantity]
AS
BEGIN
    -- Set NOCOUNT ON to avoid extra result sets
    SET NOCOUNT ON;

    -- Update AvailableQuantity in the Products table
    UPDATE p
    SET AvailableQuantity = p.Quantity - ISNULL(up.UseQuantity, 0)
    FROM [dbo].[Products] p
    LEFT JOIN (
        -- Calculate UseQuantity from UserProducts table
        SELECT 
            up.ProductID,
            COUNT(up.ID) AS UseQuantity
        FROM [dbo].[UserProducts] up
        GROUP BY up.ProductID
    ) up ON p.ID = up.ProductID;

	UPDATE p
    SET UseQuantity = ISNULL(up.UsageCount, 0)
    FROM [dbo].[Products] p
    LEFT JOIN (
        -- Calculate the count of ProductID usage from UserProducts
        SELECT 
            up.ProductID,
            COUNT(up.ID) AS UsageCount
        FROM [dbo].[UserProducts] up
        GROUP BY up.ProductID
    ) up ON p.ID = up.ProductID;

END
GO

-- %% [markdown]
-- # [dbo].[usp.UpdateUseQuantity]

-- %%
/****** Object:  StoredProcedure [dbo].[usp.UpdateUseQuantity]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE   PROCEDURE [dbo].[usp.UpdateUseQuantity]
AS
BEGIN
    -- Set NOCOUNT ON to avoid extra result sets
    SET NOCOUNT ON;

    -- Update UseQuantity in the Products table
    UPDATE p
    SET UseQuantity = ISNULL(up.UsageCount, 0)
    FROM [dbo].[Products] p
    LEFT JOIN (
        -- Calculate the count of ProductID usage from UserProducts
        SELECT 
            up.ProductID,
            COUNT(up.UserProductID) AS UsageCount
        FROM [dbo].[UserProducts] up
        GROUP BY up.ProductID
    ) up ON p.ID = up.ProductID;

END
GO

-- %% [markdown]
-- # [dbo].[usp.UpdateUserPermissions]

-- %%
/****** Object:  StoredProcedure [dbo].[usp.UpdateUserPermissions]    Script Date: 02-01-2025 11:41:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


/*
-- Execute the stored procedure
EXEC [dbo].[usp.UpdateUserPermissions];
*/

CREATE   PROCEDURE [dbo].[usp.UpdateUserPermissions]
AS
BEGIN
    -- Update Permissions to true for matching DepartmentIDs
    UPDATE U
    SET U.Permissions = 1
    FROM [dbo].[Users] U
    INNER JOIN [dbo].[Departments] D
        ON U.DepartmentID = D.ID
    WHERE D.Name IN ('Admin', 'Network and Systems Administrator');

    -- Update Permissions to false for non-matching DepartmentIDs
    UPDATE U
    SET U.Permissions = 0
    FROM [dbo].[Users] U
    WHERE U.DepartmentID NOT IN (
        SELECT ID
        FROM [dbo].[Departments]
        WHERE Name IN ('Admin', 'Network and Systems Administrator')
    );
END;
GO

-- %% [markdown]
-- # [AIMSV3]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [AIMSV3] SET  READ_WRITE 
GO
